# %%
import pandas as pd

# %%
data = {
    'apples': [3, 2, 0, 1], 
    'oranges': [0, 3, 7, 2]
}

# %%
purchase = pd.DataFrame(data)
purchase
# Out:
#    apples  oranges
# 0       3        0
# 1       2        3
# 2       0        7
# 3       1        2

# %%
type(purchase)
# Out:
# pandas.core.frame.DataFrame

# %%
print (purchase)
# Out:
#    apples  oranges
# 0       3        0
# 1       2        3
# 2       0        7
# 3       1        2

# %%
pd.mean(purchase)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-f57a5ed3c7fc> in <module>()
# ----> 1 pd.mean(purchase)
#
# AttributeError: module 'pandas' has no attribute 'mean'

# %%
purchase = pd.DataFrame(data, index=['June', 'Robert', 'Lily', 'David'])
purchase
# Out:
#         apples  oranges
# June         3        0
# Robert       2        3
# Lily         0        7
# David        1        2

# %%
purchase.loc['Lily']
# Out:
# apples     0
# oranges    7
# Name: Lily, dtype: int64

# %%
purchase.loc[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-4bbf68049e2a> in <module>()
# ----> 1 purchase.loc[0]
#
# G:\Anaconda\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1476
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#    1480     def _is_scalar_access(self, key):
#
# G:\Anaconda\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1909
#    1910         # fall thru to straight lookup
# -> 1911         self._validate_key(key, axis)
#    1912         return self._get_label(key, axis=axis)
#    1913
#
# G:\Anaconda\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1786
#    1787             try:
# ...

# %%
purchase.apples
# Out:
# June      3
# Robert    2
# Lily      0
# David     1
# Name: apples, dtype: int64

# %%
purchase['apples']
# Out:
# June      3
# Robert    2
# Lily      0
# David     1
# Name: apples, dtype: int64

# %%
import psycopg2 as pg2

# %%
conn = pg2.connect("dbname='abcDB' user='postgres' host='127.0.0.1' password='0000'")

# %%
inventoriesData = pd.read_sql_query("Select * from inventories",conn)
inventoriesData
# Out:
#    id       inv_name inv_type  buyingPrice  stock  sellingPrice
# 0   6    Smart Phone  Product        60000    254         62499
# 1  11   Water Bottle  Product           20    426            30
# 2  10  Baby Sitting   Service         6000    300         10000
# 3   7        Laundry  Service         1000   -172          2000
# 4  12            Tie  Product           50    100           100
# 5   1          Books  Product         1000     30          1500
# 6   2          Table  Service         2000    276          2300

# %%
inventoriesData.to_json('inventories.json')

# %%
quantitysold =  pd.read_sql_query("SELECT distinct inventories.inv_type as invType,(sum(sales.quantity)over(partition by inventories.inv_type)) as quantitySold from sales join inventories on sales.inv_id = inventories.id",conn)
quantitysold
# Out:
#    invtype  quantitysold
# 0  Product           254
# 1  Service           436

# %%
fileEncoding = 'utf-8'
fileOpen = open(r'C:\Users\linet\Python\jupyterNotebook\tbl_users_applicants2.csv',encoding = fileEncoding)
dataFile = pd.read_csv(fileOpen)
dataFile
# dataFile = pd.read_csv('tbl_users_applicants2.csv',encoding = fileEncoding)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-24-c16095bd8dac> in <module>()
#       1 fileEncoding = 'utf-8'
#       2 fileOpen = open(r'C:\Users\linet\Python\jupyterNotebook\tbl_users_applicants2.csv',encoding = fileEncoding)
# ----> 3 dataFile = pd.read_csv(fileOpen)
#       4 dataFile
#       5 # dataFile = pd.read_csv('tbl_users_applicants2.csv',encoding = fileEncoding)
#
# ...

# %%
dataFile2 = pd.read_json('https://jsonplaceholder.typicode.com/posts/1/comments')
dataFile2
# Out:
#                                                   body  \
# 0    laudantium enim quasi est quidem magnam volupt...
# 1    est natus enim nihil est dolore omnis voluptat...
# 2    quia molestiae reprehenderit quasi aspernatur\...
# 3    non et atque\noccaecati deserunt quas accusant...
# 4    harum non quasi et ratione\ntempore iure ex vo...
# 5    doloribus at sed quis culpa deserunt consectet...
# 6    maiores sed dolores similique labore et invent...
# 7    ut voluptatem corrupti velit\nad voluptatem ma...
# 8    sapiente assumenda molestiae atque\nadipisci l...
# 9    voluptate iusto quis nobis reprehenderit ipsum...
# 10   ut dolorum nostrum id quia aut est\nfuga est i...
# 11   expedita maiores dignissimos facilis\nipsum es...
# 12   fuga eos qui dolor rerum\ninventore corporis e...
# 13   vel quae voluptas qui exercitationem\nvoluptat...
# 14   nihil ut voluptates blanditiis autem odio dict...
# 15   iste ut laborum aliquid velit facere itaque\nq...
# ...

# %%
dataFile2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 5 columns):
# body      500 non-null object
# email     500 non-null object
# id        500 non-null int64
# name      500 non-null object
# postId    500 non-null int64
# dtypes: int64(2), object(3)
# memory usage: 19.6+ KB

# %%
dataFile2.head(50)
# Out:
#                                                  body  \
# 0   laudantium enim quasi est quidem magnam volupt...
# 1   est natus enim nihil est dolore omnis voluptat...
# 2   quia molestiae reprehenderit quasi aspernatur\...
# 3   non et atque\noccaecati deserunt quas accusant...
# 4   harum non quasi et ratione\ntempore iure ex vo...
# 5   doloribus at sed quis culpa deserunt consectet...
# 6   maiores sed dolores similique labore et invent...
# 7   ut voluptatem corrupti velit\nad voluptatem ma...
# 8   sapiente assumenda molestiae atque\nadipisci l...
# 9   voluptate iusto quis nobis reprehenderit ipsum...
# 10  ut dolorum nostrum id quia aut est\nfuga est i...
# 11  expedita maiores dignissimos facilis\nipsum es...
# 12  fuga eos qui dolor rerum\ninventore corporis e...
# 13  vel quae voluptas qui exercitationem\nvoluptat...
# 14  nihil ut voluptates blanditiis autem odio dict...
# 15  iste ut laborum aliquid velit facere itaque\nq...
# ...

# %%
dataFile2.set_index("id")
# Out:
#                                                   body  \
# id
# 1    laudantium enim quasi est quidem magnam volupt...
# 2    est natus enim nihil est dolore omnis voluptat...
# 3    quia molestiae reprehenderit quasi aspernatur\...
# 4    non et atque\noccaecati deserunt quas accusant...
# 5    harum non quasi et ratione\ntempore iure ex vo...
# 6    doloribus at sed quis culpa deserunt consectet...
# 7    maiores sed dolores similique labore et invent...
# 8    ut voluptatem corrupti velit\nad voluptatem ma...
# 9    sapiente assumenda molestiae atque\nadipisci l...
# 10   voluptate iusto quis nobis reprehenderit ipsum...
# 11   ut dolorum nostrum id quia aut est\nfuga est i...
# 12   expedita maiores dignissimos facilis\nipsum es...
# 13   fuga eos qui dolor rerum\ninventore corporis e...
# 14   vel quae voluptas qui exercitationem\nvoluptat...
# 15   nihil ut voluptates blanditiis autem odio dict...
# 16   iste ut laborum aliquid velit facere itaque\nq...
# ...

# %%
dataFile2.shape
# Out:
# (500, 5)

# %%
dataFile2.columns
# Out:
# Index(['body', 'email', 'id', 'name', 'postId'], dtype='object')

# %%
dataFile
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-b7f00c8033d7> in <module>()
# ----> 1 dataFile
#
# NameError: name 'dataFile' is not defined

# %%
dataFile2.drop_duplicates()
# Out:
#                                                   body  \
# 0    laudantium enim quasi est quidem magnam volupt...
# 1    est natus enim nihil est dolore omnis voluptat...
# 2    quia molestiae reprehenderit quasi aspernatur\...
# 3    non et atque\noccaecati deserunt quas accusant...
# 4    harum non quasi et ratione\ntempore iure ex vo...
# 5    doloribus at sed quis culpa deserunt consectet...
# 6    maiores sed dolores similique labore et invent...
# 7    ut voluptatem corrupti velit\nad voluptatem ma...
# 8    sapiente assumenda molestiae atque\nadipisci l...
# 9    voluptate iusto quis nobis reprehenderit ipsum...
# 10   ut dolorum nostrum id quia aut est\nfuga est i...
# 11   expedita maiores dignissimos facilis\nipsum es...
# 12   fuga eos qui dolor rerum\ninventore corporis e...
# 13   vel quae voluptas qui exercitationem\nvoluptat...
# 14   nihil ut voluptates blanditiis autem odio dict...
# 15   iste ut laborum aliquid velit facere itaque\nq...
# ...

# %%
dataFile2Cleaned = dataFile2.replace(' ','')
dataFile2
# Out:
#                                                   body  \
# 0    laudantium enim quasi est quidem magnam volupt...
# 1    est natus enim nihil est dolore omnis voluptat...
# 2    quia molestiae reprehenderit quasi aspernatur\...
# 3    non et atque\noccaecati deserunt quas accusant...
# 4    harum non quasi et ratione\ntempore iure ex vo...
# 5    doloribus at sed quis culpa deserunt consectet...
# 6    maiores sed dolores similique labore et invent...
# 7    ut voluptatem corrupti velit\nad voluptatem ma...
# 8    sapiente assumenda molestiae atque\nadipisci l...
# 9    voluptate iusto quis nobis reprehenderit ipsum...
# 10   ut dolorum nostrum id quia aut est\nfuga est i...
# 11   expedita maiores dignissimos facilis\nipsum es...
# 12   fuga eos qui dolor rerum\ninventore corporis e...
# 13   vel quae voluptas qui exercitationem\nvoluptat...
# 14   nihil ut voluptates blanditiis autem odio dict...
# 15   iste ut laborum aliquid velit facere itaque\nq...
# ...

# %%
conn = pg2.connect("dbname='abcDB' user='postgres' host='127.0.0.1' password='0000'")
cur = conn.cursor()
dataFile2.to_sql('jsonplaceholder',conn)

# %%
# dataFile2SQL = pd.read_sql_query("Select * from jsonplaceholder",cur)
# dataFile2SQL

# %%
dataFile3 = pd.read_csv('https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=MSFT&interval=5min&apikey=demo&datatype=csv')
dataFile3
# Out:
#               timestamp      open      high       low     close   volume
# 0   2020-01-16 16:00:00  166.0900  166.2500  165.9500  166.2100  1181699
# 1   2020-01-16 15:55:00  165.7900  166.1100  165.7900  166.0850   684449
# 2   2020-01-16 15:50:00  165.7056  165.8200  165.6200  165.7800   436045
# 3   2020-01-16 15:45:00  165.5850  165.7100  165.5825  165.7000   253961
# 4   2020-01-16 15:40:00  165.5450  165.6300  165.5300  165.5900   289564
# 5   2020-01-16 15:35:00  165.4700  165.6050  165.4600  165.5450   281739
# 6   2020-01-16 15:30:00  165.4700  165.4950  165.3800  165.4650   227678
# 7   2020-01-16 15:25:00  165.6300  165.6500  165.4501  165.4650   190806
# 8   2020-01-16 15:20:00  165.6420  165.6650  165.6300  165.6300   184550
# 9   2020-01-16 15:15:00  165.5401  165.6500  165.5300  165.6500   204557
# 10  2020-01-16 15:10:00  165.5100  165.5700  165.4800  165.5445   281623
# 11  2020-01-16 15:05:00  165.4400  165.4600  165.3900  165.3900   116232
# ...

# %%
dataFile3.to_csv('alphaVantageCSV.csv')

# %%
dataFile3Cleaned = dataFile3.replace(' ','')
# print(dataFile3Cleaned)
dataFile3Cleaned
# Out:
#               timestamp      open      high       low     close   volume
# 0   2020-01-16 16:00:00  166.0900  166.2500  165.9500  166.2100  1181699
# 1   2020-01-16 15:55:00  165.7900  166.1100  165.7900  166.0850   684449
# 2   2020-01-16 15:50:00  165.7056  165.8200  165.6200  165.7800   436045
# 3   2020-01-16 15:45:00  165.5850  165.7100  165.5825  165.7000   253961
# 4   2020-01-16 15:40:00  165.5450  165.6300  165.5300  165.5900   289564
# 5   2020-01-16 15:35:00  165.4700  165.6050  165.4600  165.5450   281739
# 6   2020-01-16 15:30:00  165.4700  165.4950  165.3800  165.4650   227678
# 7   2020-01-16 15:25:00  165.6300  165.6500  165.4501  165.4650   190806
# 8   2020-01-16 15:20:00  165.6420  165.6650  165.6300  165.6300   184550
# 9   2020-01-16 15:15:00  165.5401  165.6500  165.5300  165.6500   204557
# 10  2020-01-16 15:10:00  165.5100  165.5700  165.4800  165.5445   281623
# 11  2020-01-16 15:05:00  165.4400  165.4600  165.3900  165.3900   116232
# ...

# %%
# dataFile3Cleaned = dataFile3Cleaned.index(['Monday', 'Tuesday', 'Wednesday', 'Thursday','Friday'])
# dataFile3Cleaned

# %%
dataFile4 = pd.read_csv('IMDB_Data.csv')
dataFile4
# Out:
#      Rank                                    Title  \
# 0       1                  Guardians of the Galaxy
# 1       2                               Prometheus
# 2       3                                    Split
# 3       4                                     Sing
# 4       5                            Suicide Squad
# 5       6                           The Great Wall
# 6       7                               La La Land
# 7       8                                 Mindhorn
# 8       9                       The Lost City of Z
# 9      10                               Passengers
# 10     11  Fantastic Beasts and Where to Find Them
# 11     12                           Hidden Figures
# 12     13                                Rogue One
# 13     14                                    Moana
# 14     15                                 Colossal
# 15     16                  The Secret Life of Pets
# 16     17                            Hacksaw Ridge
# ...

# %%
dataFile4.loc[0]
# Out:
# Rank                                                                  1
# Title                                           Guardians of the Galaxy
# Genre                                           Action,Adventure,Sci-Fi
# Description           A group of intergalactic criminals are forced ...
# Director                                                     James Gunn
# Actors                Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# Year                                                               2014
# Runtime (Minutes)                                                   121
# Rating                                                              8.1
# Votes                                                            757074
# Revenue (Millions)                                               333.13
# Metascore                                                            76
# Name: 0, dtype: object

# %%
dataFile4.loc[974]
# Out:
# Rank                                                                975
# Title                                                    Queen of Katwe
# Genre                                             Biography,Drama,Sport
# Description           A Ugandan girl sees her world rapidly change a...
# Director                                                      Mira Nair
# Actors                Madina Nalwanga, David Oyelowo, Lupita Nyong'o...
# Year                                                               2016
# Runtime (Minutes)                                                   124
# Rating                                                              7.4
# Votes                                                              6753
# Revenue (Millions)                                                 8.81
# Metascore                                                            73
# Name: 974, dtype: object

# %%
dataFile4.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
key1=dataFile4.get(key=2)
print(key1)
# Out:
# None

# %%
dataFile4.Actors()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-99a391cc5e12> in <module>()
# ----> 1 dataFile4.Actors()
#
# TypeError: 'Series' object is not callable

# %%
dataFile4.head(10)
# Out:
#    Rank                    Title                       Genre  \
# 0     1  Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 1     2               Prometheus    Adventure,Mystery,Sci-Fi
# 2     3                    Split             Horror,Thriller
# 3     4                     Sing     Animation,Comedy,Family
# 4     5            Suicide Squad    Action,Adventure,Fantasy
# 5     6           The Great Wall    Action,Adventure,Fantasy
# 6     7               La La Land          Comedy,Drama,Music
# 7     8                 Mindhorn                      Comedy
# 8     9       The Lost City of Z  Action,Adventure,Biography
# 9    10               Passengers     Adventure,Drama,Romance
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# ...

# %%
dataFile4.tail()
# Out:
#      Rank                   Title                  Genre  \
# 995   996    Secret in Their Eyes    Crime,Drama,Mystery
# 996   997         Hostel: Part II                 Horror
# 997   998  Step Up 2: The Streets    Drama,Music,Romance
# 998   999            Search Party       Adventure,Comedy
# 999  1000              Nine Lives  Comedy,Family,Fantasy
#
#                                            Description          Director  \
# 995  A tight-knit team of rising investigators, alo...         Billy Ray
# 996  Three American college students studying abroa...          Eli Roth
# 997  Romantic sparks occur between two dance studen...        Jon M. Chu
# 998  A pair of friends embark on a mission to reuni...    Scot Armstrong
# 999  A stuffy businessman finds himself trapped ins...  Barry Sonnenfeld
#
#                                                 Actors  Year  \
# 995  Chiwetel Ejiofor, Nicole Kidman, Julia Roberts...  2015
# ...

# %%
dataFile4.columns[0:5]
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director'], dtype='object')

# %%
dataFile4.columns[4]
# Out:
# 'Director'

# %%
dataFile4.columns['Director']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-47-192fa5d5286b> in <module>()
# ----> 1 dataFile4.columns['Director']
#
# G:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in __getitem__(self, key)
#    2082
#    2083         if is_scalar(key):
# -> 2084             return getitem(key)
#    2085
#    2086         if isinstance(key, slice):
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
type(dataFile4.Title)
# Out:
# pandas.core.series.Series

# %%
type([dataFile4['Title']])
# Out:
# list

# %%
type(dataFile4[['Title']])
# Out:
# pandas.core.frame.DataFrame

# %%
dataFile5 = dataFile4[['Title']]
type(dataFile5)
# Out:
# pandas.core.frame.DataFrame

# %%
# dataFile5.head
dataFile4[['Title']].head()
# Out:
#                      Title
# 0  Guardians of the Galaxy
# 1               Prometheus
# 2                    Split
# 3                     Sing
# 4            Suicide Squad

# %%
dataFile4 = pd.read_csv('IMDB_Data.csv',index_col = 'Title')
dataFile4
# Out:
#                                          Rank                       Genre  \
# Title
# Guardians of the Galaxy                     1     Action,Adventure,Sci-Fi
# Prometheus                                  2    Adventure,Mystery,Sci-Fi
# Split                                       3             Horror,Thriller
# Sing                                        4     Animation,Comedy,Family
# Suicide Squad                               5    Action,Adventure,Fantasy
# The Great Wall                              6    Action,Adventure,Fantasy
# La La Land                                  7          Comedy,Drama,Music
# Mindhorn                                    8                      Comedy
# The Lost City of Z                          9  Action,Adventure,Biography
# Passengers                                 10     Adventure,Drama,Romance
# Fantastic Beasts and Where to Find Them    11    Adventure,Family,Fantasy
# Hidden Figures                             12     Biography,Drama,History
# ...

# %%
dataFileDuplicates = dataFile4.append(dataFile4)
dataFileDuplicates.shape
# Out:
# (2000, 11)

# %%
dataFile6 = dataFileDuplicates.drop_duplicates()
dataFile6
dataFile6.shape
# Out:
# (1000, 11)

# %%
dataFile4.rename(columns={
        'Runtime (Minutes)': 'Runtime', 
        'Revenue (Millions)': 'Revenue_millions'
    }, inplace=True)
dataFile4.columns
# Out:
# Index(['Rank', 'Genre', 'Description', 'Director', 'Actors', 'Year', 'Runtime',
#        'Rating', 'Votes', 'Revenue_millions', 'Metascore'],
#       dtype='object')

# %% [markdown]
# ###Learning Comprehension in Python

# %%
cd = [x for x in range(0,15) if x%2==0]
cd
# Out:
# [0, 2, 4, 6, 8, 10, 12, 14]

# %% [markdown]
# ###Trying out comprehension

# %%
for col in dataFile4:
    print(col)
# Out:
# Rank
# Genre
# Description
# Director
# Actors
# Year
# Runtime
# Rating
# Votes
# Revenue_millions
# Metascore

# %%
newComp = [col.lower() for col in dataFile4]
newComp
# Out:
# ['rank',
#  'genre',
#  'description',
#  'director',
#  'actors',
#  'year',
#  'runtime',
#  'rating',
#  'votes',
#  'revenue_millions',
#  'metascore']

# %%
dataFile4.columns=newComp
dataFile4.columns
# Out:
# Index(['rank', 'genre', 'description', 'director', 'actors', 'year', 'runtime',
#        'rating', 'votes', 'revenue_millions', 'metascore'],
#       dtype='object')

# %%
dataFile4.head()
# Out:
#                          rank                     genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
#
#                                                                description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# Sing                     In a city of humanoid animals, a hustling thea...
# Suicide Squad            A secret government agency recruits some of th...
#
#                                      director  \
# Title
# Guardians of the Galaxy            James Gunn
# Prometheus                       Ridley Scott
# ...

# %%
dataFile4['rating'] = [x+2 for x in dataFile4['rating']]
dataFile4['rating']
# Out:
# Title
# Guardians of the Galaxy                    10.1
# Prometheus                                  9.0
# Split                                       9.3
# Sing                                        9.2
# Suicide Squad                               8.2
# The Great Wall                              8.1
# La La Land                                 10.3
# Mindhorn                                    8.4
# The Lost City of Z                          9.1
# Passengers                                  9.0
# Fantastic Beasts and Where to Find Them     9.5
# Hidden Figures                              9.8
# Rogue One                                   9.9
# Moana                                       9.7
# Colossal                                    8.4
# The Secret Life of Pets                     8.6
# Hacksaw Ridge                              10.2
# Jason Bourne                                8.7
# Lion                                       10.1
# ...

# %%
dataFile4.isnull()
# Out:
#                                           rank  genre  description  director  \
# Title
# Guardians of the Galaxy                  False  False        False     False
# Prometheus                               False  False        False     False
# Split                                    False  False        False     False
# Sing                                     False  False        False     False
# Suicide Squad                            False  False        False     False
# The Great Wall                           False  False        False     False
# La La Land                               False  False        False     False
# Mindhorn                                 False  False        False     False
# The Lost City of Z                       False  False        False     False
# Passengers                               False  False        False     False
# Fantastic Beasts and Where to Find Them  False  False        False     False
# ...

# %%
dataFile4.isnull().count()
# Out:
# rank                1000
# genre               1000
# description         1000
# director            1000
# actors              1000
# year                1000
# runtime             1000
# rating              1000
# votes               1000
# revenue_millions    1000
# metascore           1000
# dtype: int64

# %%
dataFile4.isnull().sum()
# Out:
# rank                  0
# genre                 0
# description           0
# director              0
# actors                0
# year                  0
# runtime               0
# rating                0
# votes                 0
# revenue_millions    128
# metascore            64
# dtype: int64

# %%
dataFile4NullOp = dataFile4.dropna()
dataFile4NullOp.isnull().sum()
# Out:
# rank                0
# genre               0
# description         0
# director            0
# actors              0
# year                0
# runtime             0
# rating              0
# votes               0
# revenue_millions    0
# metascore           0
# dtype: int64

# %%
dataFile4NullOp.shape
# Out:
# (838, 11)

# %%
dataFile4.shape
# Out:
# (1000, 11)

# %%
dataFile4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, Guardians of the Galaxy to Nine Lives
# Data columns (total 11 columns):
# rank                1000 non-null int64
# genre               1000 non-null object
# description         1000 non-null object
# director            1000 non-null object
# actors              1000 non-null object
# year                1000 non-null int64
# runtime             1000 non-null int64
# rating              1000 non-null float64
# votes               1000 non-null int64
# revenue_millions    872 non-null float64
# metascore           936 non-null float64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 133.8+ KB

# %%
dataFile4NullOpCol = dataFile4.dropna(axis=1)
dataFile4NullOpCol.isnull().sum()
dataFile4NullOpCol.shape
# Out:
# (1000, 9)

# %%
dataFile4NullOpCol.columns.value_counts()
# Out:
# description    1
# actors         1
# rating         1
# genre          1
# director       1
# rank           1
# year           1
# votes          1
# runtime        1
# dtype: int64

# %%
revenue = dataFile4['revenue_millions']
revenue.head()
# Out:
# Title
# Guardians of the Galaxy    333.13
# Prometheus                 126.46
# Split                      138.12
# Sing                       270.32
# Suicide Squad              325.02
# Name: revenue_millions, dtype: float64

# %%
revenueMean = revenue.mean()
revenueMean
# Out:
# 82.95637614678897

# %%
revenue.fillna(revenueMean, inplace=True)
revenue.isnull().sum()
# Out:
# 0

# %%
dataFile8 = revenue.fillna(revenueMean)
dataFile8.shape
type(dataFile8)

# dataFile8.isnull().sum()
# Out:
# pandas.core.series.Series

# %%
dataFile8.describe
# Out:
# <bound method NDFrame.describe of Title
# Guardians of the Galaxy                    333.130000
# Prometheus                                 126.460000
# Split                                      138.120000
# Sing                                       270.320000
# Suicide Squad                              325.020000
# The Great Wall                              45.130000
# La La Land                                 151.060000
# Mindhorn                                    82.956376
# The Lost City of Z                           8.010000
# Passengers                                 100.010000
# Fantastic Beasts and Where to Find Them    234.020000
# Hidden Figures                             169.270000
# Rogue One                                  532.170000
# Moana                                      248.750000
# Colossal                                     2.870000
# The Secret Life of Pets                    368.310000
# Hacksaw Ridge                               67.120000
# ...

# %%
dataFile9 = dataFile4.fillna(revenueMean)
dataFile9.shape
# Out:
# (1000, 11)

# %%
dataFile9.isnull().sum()
# Out:
# rank                0
# genre               0
# description         0
# director            0
# actors              0
# year                0
# runtime             0
# rating              0
# votes               0
# revenue_millions    0
# metascore           0
# dtype: int64

# %%
dataFile10 = dataFile4.copy()

# %%
dataFile10
# Out:
#                                          rank                       genre  \
# Title
# Guardians of the Galaxy                     1     Action,Adventure,Sci-Fi
# Prometheus                                  2    Adventure,Mystery,Sci-Fi
# Split                                       3             Horror,Thriller
# Sing                                        4     Animation,Comedy,Family
# Suicide Squad                               5    Action,Adventure,Fantasy
# The Great Wall                              6    Action,Adventure,Fantasy
# La La Land                                  7          Comedy,Drama,Music
# Mindhorn                                    8                      Comedy
# The Lost City of Z                          9  Action,Adventure,Biography
# Passengers                                 10     Adventure,Drama,Romance
# Fantastic Beasts and Where to Find Them    11    Adventure,Family,Fantasy
# Hidden Figures                             12     Biography,Drama,History
# ...

# %%
dataFile10['revenue_millions'] = revenue

# %%
dataFile10.isnull().sum()
# Out:
# rank                 0
# genre                0
# description          0
# director             0
# actors               0
# year                 0
# runtime              0
# rating               0
# votes                0
# revenue_millions     0
# metascore           64
# dtype: int64

# %%
metascoreCol = dataFile4['metascore']
metascoreCol.head()
# Out:
# Title
# Guardians of the Galaxy    76.0
# Prometheus                 65.0
# Split                      62.0
# Sing                       59.0
# Suicide Squad              40.0
# Name: metascore, dtype: float64

# %%
metascoreMean = metascoreCol.mean()

# %%
metascoreMean
# Out:
# 58.98504273504273

# %%
metascoreCol.fillna(metascoreMean, inplace=True)

# %%
dataFile10['metascore'] = metascoreCol

# %%
dataFile10.isnull().sum()
# Out:
# rank                0
# genre               0
# description         0
# director            0
# actors              0
# year                0
# runtime             0
# rating              0
# votes               0
# revenue_millions    0
# metascore           0
# dtype: int64

# %%
plot1 = dataFile4.plot(kind='scatter', x='rating', y='revenue_millions', title='Revenue (millions) vs Rating');

# %%
plot2 = dataFile4['rating'].plot(kind='hist', title='Rating');

# %%
plot3 = dataFile4['rating'].plot(kind="box");
