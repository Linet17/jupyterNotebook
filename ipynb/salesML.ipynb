# %%
import pandas as pd

# %%
import flask

# %%
from flask import Flask

# %%
import psycopg2

# %%
from flask_sqlalchemy import SQLAlchemy

# %%
import pickle

# %%
import matplotlib.pyplot as mpl

# %%
# conn = psycopg2.connect("dbname='abcDB',user='postgres',host='localhost',password='0000'")
conn = psycopg2.connect('postgresql://postgres:0000@127.0.0.1:5432/abcDB')

# %%
stats = pd.read_sql_query("select extract(month from created_at),sum(case when extract(year from created_at) = 2009 then i.selling_price*s.quantity end) as sales2009,sum(case when extract(year from created_at) = 2010 then i.selling_price*s.quantity end) as sales2010,sum(case when extract(year from created_at) = 2011 then i.selling_price*s.quantity end) as sales2011,sum(case when extract(year from created_at) = 2012 then i.selling_price*s.quantity end) as sales2012,sum(case when extract(year from created_at) = 2013 then i.selling_price*s.quantity end) as sales2013,sum(case when extract(year from created_at) = 2014 then i.selling_price*s.quantity end) as sales2014,sum(case when extract(year from created_at) = 2015 then i.selling_price*s.quantity end) as sales2015,sum(case when extract(year from created_at) = 2016 then i.selling_price*s.quantity end) as sales2016,sum(case when extract(year from created_at) = 2017 then i.selling_price*s.quantity end) as sales2017,sum(case when extract(year from created_at) = 2018 then i.selling_price*s.quantity end) as sales2018,sum(case when extract(year from created_at) = 2019 then i.selling_price*s.quantity end) as sales2019 from sales s join inventories as i on s.inv_id = i.id group by extract(month from created_at),extract(year from created_at) order BY extract(month from created_at),extract(year from created_at)",conn);

# %%
stats
# Out:
#      date_part  sales2009  sales2010  sales2011  sales2012  sales2013  \
# 0          1.0        NaN     5606.0        NaN        NaN        NaN
# 1          1.0        NaN        NaN     6303.0        NaN        NaN
# 2          1.0        NaN        NaN        NaN     7956.0        NaN
# 3          1.0        NaN        NaN        NaN        NaN     4132.0
# 4          1.0        NaN        NaN        NaN        NaN        NaN
# 5          1.0        NaN        NaN        NaN        NaN        NaN
# 6          1.0        NaN        NaN        NaN        NaN        NaN
# 7          1.0        NaN        NaN        NaN        NaN        NaN
# 8          1.0        NaN        NaN        NaN        NaN        NaN
# 9          1.0        NaN        NaN        NaN        NaN        NaN
# 10         2.0        NaN     2423.0        NaN        NaN        NaN
# 11         2.0        NaN        NaN     2137.0        NaN        NaN
# ...

# %%
import sklearn

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import train_test_split

# %%
from matplotlib import pyplot as plt

# %%
stats2 = stats.set_index("date_part")

# %%
stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 12 columns):
# date_part    122 non-null float64
# sales2009    2 non-null float64
# sales2010    12 non-null float64
# sales2011    12 non-null float64
# sales2012    12 non-null float64
# sales2013    12 non-null float64
# sales2014    12 non-null float64
# sales2015    12 non-null float64
# sales2016    12 non-null float64
# sales2017    12 non-null float64
# sales2018    12 non-null float64
# sales2019    12 non-null float64
# dtypes: float64(12)
# memory usage: 11.5 KB

# %%
stats.describe()
# Out:
#         date_part    sales2009     sales2010    sales2011    sales2012  \
# count  122.000000     2.000000     12.000000    12.000000    12.000000
# mean     6.581967  5678.000000   5998.000000  4905.666667  6469.666667
# std      3.496965   363.452886   3073.013091  2634.855260  2396.631626
# min      1.000000  5421.000000   2423.000000   940.000000  2140.000000
# 25%      4.000000  5549.500000   4566.750000  2553.250000  5816.750000
# 50%      7.000000  5678.000000   5285.000000  5656.000000  6828.500000
# 75%     10.000000  5806.500000   6925.750000  6870.750000  7875.000000
# max     12.000000  5935.000000  14142.000000  8675.000000  9414.000000
#
#          sales2013    sales2014    sales2015     sales2016    sales2017  \
# count    12.000000    12.000000    12.000000     12.000000    12.000000
# mean   5026.500000  5514.416667  5408.750000   6709.333333  4926.000000
# std    2260.600664  1488.684255  1991.599683   5152.261892  1020.439299
# ...

# %%
dataset= stats.copy

# %%
dataset
# Out:
# <bound method NDFrame.copy of      date_part  sales2009  sales2010  sales2011  sales2012  sales2013  \
# 0          1.0        NaN     5606.0        NaN        NaN        NaN
# 1          1.0        NaN        NaN     6303.0        NaN        NaN
# 2          1.0        NaN        NaN        NaN     7956.0        NaN
# 3          1.0        NaN        NaN        NaN        NaN     4132.0
# 4          1.0        NaN        NaN        NaN        NaN        NaN
# 5          1.0        NaN        NaN        NaN        NaN        NaN
# 6          1.0        NaN        NaN        NaN        NaN        NaN
# 7          1.0        NaN        NaN        NaN        NaN        NaN
# 8          1.0        NaN        NaN        NaN        NaN        NaN
# 9          1.0        NaN        NaN        NaN        NaN        NaN
# 10         2.0        NaN     2423.0        NaN        NaN        NaN
# 11         2.0        NaN        NaN     2137.0        NaN        NaN
# ...

# %%
print(dataset)
# Out:
# <bound method NDFrame.copy of      date_part  sales2009  sales2010  sales2011  sales2012  sales2013  \
# 0          1.0        NaN     5606.0        NaN        NaN        NaN
# 1          1.0        NaN        NaN     6303.0        NaN        NaN
# 2          1.0        NaN        NaN        NaN     7956.0        NaN
# 3          1.0        NaN        NaN        NaN        NaN     4132.0
# 4          1.0        NaN        NaN        NaN        NaN        NaN
# 5          1.0        NaN        NaN        NaN        NaN        NaN
# 6          1.0        NaN        NaN        NaN        NaN        NaN
# 7          1.0        NaN        NaN        NaN        NaN        NaN
# 8          1.0        NaN        NaN        NaN        NaN        NaN
# 9          1.0        NaN        NaN        NaN        NaN        NaN
# 10         2.0        NaN     2423.0        NaN        NaN        NaN
# 11         2.0        NaN        NaN     2137.0        NaN        NaN
# ...
